# %% [markdown]
# # **Bank Customer  Prediction**

# %% [markdown]
# ### **Data Preeprocessing**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as srs

# %matplotlib inline

# %%
data = pd.read_csv("Churn_Modelling.csv")
data.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
data.shape
# Out:
# (10000, 14)

# %% [markdown]
# ### **Chack The NullVelues**

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ## **Feature Enginnering**

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
data.drop('CustomerId', axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['RowNumber', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
data = data[['RowNumber', 'CreditScore', 'Geography', 'Gender', 'Age',
       'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
       'EstimatedSalary', 'Exited']]
data.head()
# Out:
#    RowNumber  CreditScore Geography  ... IsActiveMember  EstimatedSalary  Exited
# 0          1          619    France  ...              1        101348.88       1
# 1          2          608     Spain  ...              1        112542.58       0
# 2          3          502    France  ...              0        113931.57       1
# 3          4          699    France  ...              0         93826.63       0
# 4          5          850     Spain  ...              1         79084.10       0
#
# [5 rows x 12 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Gender'] = le.fit_transform(data['Gender'])

# %%
data.head()
# Out:
#    RowNumber  CreditScore Geography  ...  IsActiveMember  EstimatedSalary  Exited
# 0          1          619    France  ...               1        101348.88       1
# 1          2          608     Spain  ...               1        112542.58       0
# 2          3          502    France  ...               0        113931.57       1
# 3          4          699    France  ...               0         93826.63       0
# 4          5          850     Spain  ...               1         79084.10       0
#
# [5 rows x 12 columns]

# %%
data['Geography'].unique()
# Out:
# array(['France', 'Spain', 'Germany'], dtype=object)

# %%
data = pd.get_dummies(data, drop_first=True)
data.head()
# Out:
#    RowNumber  CreditScore  Gender  ...  Exited  Geography_Germany  Geography_Spain
# 0          1          619       0  ...       1                  0                0
# 1          2          608       0  ...       0                  0                1
# 2          3          502       0  ...       1                  0                0
# 3          4          699       0  ...       0                  0                0
# 4          5          850       0  ...       0                  0                1
#
# [5 rows x 13 columns]

# %%
data.shape
# Out:
# (10000, 13)

# %% [markdown]
# ## **Coreletions & Heat Map**

# %%
data.corr()
# Out:
#                    RowNumber  CreditScore  ...  Geography_Germany  Geography_Spain
# RowNumber           1.000000     0.005840  ...          -0.000044        -0.009905
# CreditScore         0.005840     1.000000  ...           0.005538         0.004780
# Gender              0.018196    -0.002857  ...          -0.024628         0.016889
# Age                 0.000783    -0.003965  ...           0.046897        -0.001685
# Tenure             -0.006495     0.000842  ...          -0.000567         0.003868
# Balance            -0.009067     0.006268  ...           0.401110        -0.134892
# NumOfProducts       0.007246     0.012238  ...          -0.010419         0.009039
# HasCrCard           0.000599    -0.005458  ...           0.010577        -0.013480
# IsActiveMember      0.012044     0.025651  ...          -0.020486         0.016732
# EstimatedSalary    -0.005988    -0.001384  ...           0.010297        -0.006482
# ...

# %%
srs.pairplot(data, hue='Exited')

# %% [markdown]
# ## **Applay Algoridham**

# %%
X =  data.drop('Exited', axis=1)
y = data['Exited']

# %%
X.head()
# Out:
#    RowNumber  CreditScore  ...  Geography_Germany  Geography_Spain
# 0          1          619  ...                  0                0
# 1          2          608  ...                  0                1
# 2          3          502  ...                  0                0
# 3          4          699  ...                  0                0
# 4          5          850  ...                  0                1
#
# [5 rows x 12 columns]

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Exited, dtype: int64

# %% [markdown]
# ## **X,y Splite**

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [0.10869381 0.10962738 0.01792721 0.21101783 0.08901939 0.11412764
#  0.13820788 0.02325615 0.03741816 0.10820499 0.0294139  0.01308567]

# %%
feat_importances = pd.Series(model.feature_importances_ , index = X.columns)
feat_importances.nlargest(5).plot(kind = 'barh')
plt.show()

# %% [markdown]
# ## **Apply Algoridhams**

# %% [markdown]
# ### **Train-Test Splite**

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 7)

# %%
from xgboost import XGBClassifier
classifire = XGBClassifier()
classifire.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1)

# %%
classifire.score(X_test,y_test)
# Out:
# 0.876

# %% [markdown]
# ### **K Fold CV**

# %%
from sklearn.model_selection import cross_val_score
classifire = XGBClassifier()

# %%
score = cross_val_score(classifire, X, y, cv=10, scoring = 'accuracy')
print(score)
# Out:
# [0.874 0.86  0.871 0.865 0.863 0.85  0.868 0.88  0.858 0.819]

# %%
print(score.mean())
# Out:
# 0.8608
